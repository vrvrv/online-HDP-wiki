# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
log_path = './corpus-None-kappa-0.5-tau-1-batchsize-15/log.dat'
log = pd.read_table(log_path, sep = ' ')

# %%
plt.figure(figsize=(20,10))
plt.plot(log['score'], 'bo--',linewidth = 2)
plt.plot(log['unseen.score'], 'r^-')

plt.legend(['score', 'unseen.score'], loc='lower right', fontsize = 20)
plt.xlabel("Iteration", fontsize=20)
plt.xlim(0, 50)
plt.show()

# %%
log
# Out:
#      iteration  time  doc.count         score  word.count  unseen.score  \
# 0            1     0         15 -208707.54934        2370 -208707.54934
# 1            2     1         30  -21611.42549        1852   -7348.53295
# 2            3     2         45   -9640.31310        1680       0.00000
# 3            4     3         60 -209865.18108        2718 -209865.18108
# 4            5     3         75  -49020.42484        2687  -33821.73820
# ..         ...   ...        ...           ...         ...           ...
# 496        497   343       7455  -10770.17840        1336       0.00000
# 497        498   344       7470   -9283.40865        1142       0.00000
# 498        499   344       7485   -8152.68800         969       0.00000
# 499        500   345       7500   -9569.83795        1167       0.00000
# 500        501   346       7515   -9547.29258        1189       0.00000
#
#      unseen.word.count
# 0                 2370
# 1                  117
# 2                    0
# ...
